# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.linear_model import LinearRegression

# %%
np.random.seed(0)
n=20   # Number of data points
x=np.linspace(0, 10, n)
randoms = np.random.randn(n)
y=x*2 + 1 + 1*randoms # Standard deviation 1
x
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
randoms
# Out:
# array([ 1.76405235,  0.40015721,  0.97873798,  2.2408932 ,  1.86755799,
#        -0.97727788,  0.95008842, -0.15135721, -0.10321885,  0.4105985 ,
#         0.14404357,  1.45427351,  0.76103773,  0.12167502,  0.44386323,
#         0.33367433,  1.49407907, -0.20515826,  0.3130677 , -0.85409574])

# %%
y
# Out:
# array([ 2.76405235,  2.45278879,  4.08400114,  6.39878794,  7.07808431,
#         5.28588001,  8.26587789,  8.21706384,  9.31783378, 10.88428271,
#        11.67035936, 14.03322088, 14.39261667, 14.80588554, 16.18070534,
#        17.12314801, 19.33618434, 18.68957858, 20.26043612, 20.14590426])

# %%
pairs = np.stack((x,y),axis=1)
pairs
# Out:
# array([[ 0.        ,  2.76405235],
#        [ 0.52631579,  2.45278879],
#        [ 1.05263158,  4.08400114],
#        [ 1.57894737,  6.39878794],
#        [ 2.10526316,  7.07808431],
#        [ 2.63157895,  5.28588001],
#        [ 3.15789474,  8.26587789],
#        [ 3.68421053,  8.21706384],
#        [ 4.21052632,  9.31783378],
#        [ 4.73684211, 10.88428271],
#        [ 5.26315789, 11.67035936],
#        [ 5.78947368, 14.03322088],
#        [ 6.31578947, 14.39261667],
#        [ 6.84210526, 14.80588554],
#        [ 7.36842105, 16.18070534],
#        [ 7.89473684, 17.12314801],
#        [ 8.42105263, 19.33618434],
#        [ 8.94736842, 18.68957858],
#        [ 9.47368421, 20.26043612],
#        [10.        , 20.14590426]])

# %%
model=LinearRegression(fit_intercept=True)
model.fit(x[:,np.newaxis], y)
xfit=np.linspace(0,10,100)
yfit=model.predict(xfit[:, np.newaxis])
plt.plot(xfit,yfit, color="black")
plt.plot(x,y, 'o')
plt.plot(np.vstack([x,x]), np.vstack([y, model.predict(x[:, np.newaxis])]), color="red");

# %%
np.info(x[:,np.newaxis])
# Out:
# class:  ndarray
# shape:  (20, 1)
# strides:  (8, 0)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x600002a0c280
# byteorder:  little
# byteswap:  False
# type: float64

# %%
np.info(y)
# Out:
# class:  ndarray
# shape:  (20,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x600002a0c5a0
# byteorder:  little
# byteswap:  False
# type: float64

# %%
print("Parameters:", model.coef_, model.intercept_)
print("Coefficient:", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Parameters: [1.88627741] 2.13794752053413
# Coefficient: 1.8862774144823014
# Intercept: 2.13794752053413

# %%
# Множинна регресія. Маємо 3 приклади комбінацій з 3х незалежних змінних X1, X2, X3. Маємо масив з трьох відповідних їм прикладів залежної змінної Y
sample1=np.array([1,2,3])   # The three explanatory variables have values 1, 2, and 3, respectively
sample2=np.array([4,5,6])   # Another example of values of explanatory variables
sample3=np.array([7,8,10])   # ...
y=np.array([15,39,66]) + np.random.randn(3)   # For values 1,2, and 3 of explanatory variables, the value y=15 was observed, and so on.

# %%
model2=LinearRegression(fit_intercept=False)
x=np.vstack([sample1,sample2,sample3])
model2.fit(x, y)
model2.coef_, model2.intercept_
# Out:
# (array([5.69493795e+00, 3.36972233e+00, 4.20919214e-03]), 0.0)

# %%
b=model2.coef_[:, np.newaxis]
float_formatter = np.vectorize("{:.2f}".format)
print("x:\n", x)
b_formatted = vectorized_formatter(b)
print("b:\n", b_formatted)
print("y:\n", y[:, np.newaxis])
print("product:\n", np.matmul(x, b))
# Out:
# x:
#  [[ 1  2  3]
#  [ 4  5  6]
#  [ 7  8 10]]
# b:
#  [['5.69']
#  ['3.37']
#  ['0.00']]
# y:
#  [[12.44701018]
#  [39.6536186 ]
#  [66.8644362 ]]
# product:
#  [[12.44701018]
#  [39.6536186 ]
#  [66.8644362 ]]

# %%
#Поліноміальна регресія
x=np.linspace(-50,150,50)
y=0.15*x**3 - 20*x**2 + 5*x - 4 + 5000*np.random.randn(50)
plt.scatter(x, y, color="black")

# %%
model_linear=LinearRegression(fit_intercept=True)
model_squared=LinearRegression(fit_intercept=True)
model_cubic=LinearRegression(fit_intercept=True)
x2=x**2
x3=x**3
model_linear.fit(np.vstack([x]).T, y)
model_squared.fit(np.vstack([x,x2]).T, y)
model_cubic.fit(np.vstack([x,x2,x3]).T, y)
xf=np.linspace(-50,150, 50)
yf_linear=model_linear.predict(np.vstack([x]).T)
yf_squared=model_squared.predict(np.vstack([x,x2]).T)
yf_cubic=model_cubic.predict(np.vstack([x,x2,x3]).T)
plt.scatter(x, y, color="black")
plt.plot(xf,yf_linear, label="linear")
plt.plot(xf,yf_squared, label="squared")
plt.plot(xf,yf_cubic, label="cubic")
plt.legend()
print("Cubic Regression")
print("Coefficients:", model_cubic.coef_)
print("Intercept:", model_cubic.intercept_)
# Out:
# Cubic Regression
# Coefficients: [-36.65414588 -20.17228669   0.15359003]
# Intercept: -167.16046606414602

# %%
np.vstack([x,x2,x3]).T
# Out:
# array([[-5.00000000e+01,  2.50000000e+03, -1.25000000e+05],
#        [-4.59183673e+01,  2.10849646e+03, -9.68187150e+04],
#        [-4.18367347e+01,  1.75031237e+03, -7.32273542e+04],
#        [-3.77551020e+01,  1.42544773e+03, -5.38179245e+04],
#        [-3.36734694e+01,  1.13390254e+03, -3.81824325e+04],
#        [-2.95918367e+01,  8.75676801e+02, -2.59128849e+04],
#        [-2.55102041e+01,  6.50770512e+02, -1.66012886e+04],
#        [-2.14285714e+01,  4.59183673e+02, -9.83965015e+03],
#        [-1.73469388e+01,  3.00916285e+02, -5.21997637e+03],
#        [-1.32653061e+01,  1.75968347e+02, -2.33427398e+03],
#        [-9.18367347e+00,  8.43398584e+01, -7.74549720e+02],
#        [-5.10204082e+00,  2.60308205e+01, -1.32810309e+02],
